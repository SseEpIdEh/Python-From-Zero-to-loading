# %% [markdown]
# # matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,4] ,[-1,3,5,7], 'b+')

# %%
t= np.arange(0, 5, .2)
t
plt.plot(t,t, 'r-.', t, t**2,'bs', t, t**3, 'g^')

# %%
data = {
    'a': np.arange(500),
    'b': np.random.randint(0, 50, 50),
    'c': np.random.randn(500)
}

# %%
plt.scatter(data['a'], data['c'])
